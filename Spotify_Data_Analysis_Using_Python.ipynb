# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks=pd.read_csv("tracks.csv")
df_tracks.sample(5)
# Out:
#                           id                              name  popularity  \
# 1433  2mVkVHKBoG54PaUJIuKw5N              Tita - Remasterizado         0.0
# 60    2MHbLEapczIltPOYYEzQtE     Como una Flor - Remasterizado         0.0
# 4217  1eZ5JqX9fS4XqzEb0h9Ugh  Ballade No. 1 in G Minor, Op. 23         1.0
# 1644  5LEFfke567lqg4UBO1Vz5Z       Глава 3. Часть 1.11 - Кюхля         0.0
# 1930  0o5rGmxu61uteBIMSym5fK                    Muskrat Ramble         9.0
#
#       duration_ms  explicit                                   artists  \
# 1433     160867.0       0.0                      ['Francisco Canaro']
# 60       151040.0       0.0                       ['Ignacio Corsini']
# 4217     546760.0       0.0  ['Frédéric Chopin', 'Vladimir Horowitz']
# 1644     211700.0       0.0                          ['Юрий Тынянов']
# 1930     150160.0       0.0        ['Louis Armstrong & His Hot Five']
#
#                                              id_artists release_date  \
# 1433                         ['2maQMqxNnlRrBrS1oAsrX9']   1925-07-12
# 60                           ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4217  ['7y97mc3bZRFXzT2szRM4L4', '4Ws5hSoABAwvGJ4LhH...         1928
# 1644                         ['0a39oecVf6UdscqWdiK1ny']   1925-03-24
# 1930                         ['0t4VVR2T9Sb0z3NdDdEU6S']         1926
#
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 1433         0.630   0.309   5.0   -15.324   0.0       0.0511         0.996
# 60           0.218   0.394  10.0   -19.492   0.0       0.0388         0.981
# 4217         0.323   0.176   7.0   -19.565   0.0       0.0399         0.987
# 1644         0.756   0.150   1.0   -20.817   1.0       0.9520         0.789
# 1930         0.665   0.366   8.0    -9.064   1.0       0.2120         0.982
#
#       instrumentalness  liveness  valence    tempo  time_signature
# 1433             0.788    0.3170   0.8370  126.717             4.0
# 60               0.301    0.5050   0.7490   82.287             4.0
# 4217             0.900    0.3740   0.0443   82.435             4.0
# 1644             0.000    0.4580   0.6100  110.025             3.0
# 1930             0.666    0.0763   0.8540  183.755             4.0

# %%
#null values

df_tracks.isnull().sum()
# Out:
# id                  0
# name                1
# popularity          1
# duration_ms         1
# explicit            1
# artists             1
# id_artists          1
# release_date        1
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# time_signature      1
# dtype: int64

# %%
df_tracks=df_tracks.dropna()

# %%
df_tracks.isnull().sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10143 entries, 0 to 10142
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10143 non-null  object
#  1   name              10143 non-null  object
#  2   popularity        10143 non-null  float64
#  3   duration_ms       10143 non-null  float64
#  4   explicit          10143 non-null  float64
#  5   artists           10143 non-null  object
#  6   id_artists        10143 non-null  object
#  7   release_date      10143 non-null  object
#  8   danceability      10143 non-null  float64
#  9   energy            10143 non-null  float64
#  10  key               10143 non-null  float64
#  11  loudness          10143 non-null  float64
#  12  mode              10143 non-null  float64
#  13  speechiness       10143 non-null  float64
#  14  acousticness      10143 non-null  float64
#  15  instrumentalness  10143 non-null  float64
#  16  liveness          10143 non-null  float64
#  17  valence           10143 non-null  float64
#  18  tempo             10143 non-null  float64
#  19  time_signature    10143 non-null  float64
# dtypes: float64(15), object(5)
# memory usage: 1.6+ MB

# %%
sorted_df=df_tracks.sort_values('popularity',ascending=True).head()
sorted_df
# Out:
#                           id                                  name  \
# 5071  2Zd0nx3WAn6ePpKGonA3wb          Casabianca (Carroll Gibbons)
# 6069  1qcGdG8ON66v9hOLNJEsOr                     Thodorakis Grivas
# 6068  1pxW7GqOJETsVzph4wJqJU  Melenita a la Garcón - Remasterizado
# 6067  1pw5YLbyvd3h8xmxBRXhfz                    The Thrill Is Gone
# 6066  1pq7Hrv92ewzuBNOymxYTZ          Ας πάν' να δουν τα μάτια μου
#
#       popularity  duration_ms  explicit                            artists  \
# 5071         0.0     190347.0       0.0                ['Carroll Gibbons']
# 6069         0.0     193600.0       0.0               ['Kostas Roukounas']
# 6068         0.0     175493.0       0.0  ['Francisco Canaro', 'Luis Díaz']
# 6067         0.0     164219.0       0.0                 ['Robert Francis']
# 6066         0.0     161067.0       0.0            ['Αντώνης Διαμαντίδης']
#
#                                              id_artists release_date  \
# 5071                         ['7IFehwNMIwBSIf40iX0gm9']         1929
# 6069                         ['0CP4YYMRHUeCbsHDrIMzzq']   1930-01-01
# 6068  ['2maQMqxNnlRrBrS1oAsrX9', '6Lp13HWGjmaUEU5p2F...   1930-12-03
# 6067                         ['42LOtwpoBAnVLUqPJ8gwFy']         1930
# 6066                         ['2CjOxjOHsK5lEFVwsxabBX']   1930-01-01
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5071         0.766  0.2270  3.0   -16.313   1.0       0.1030         0.977
# 6069         0.389  0.3060  4.0    -8.669   0.0       0.0930         0.988
# 6068         0.802  0.4960  2.0    -5.420   1.0       0.2540         0.933
# 6067         0.430  0.0935  8.0   -14.250   1.0       0.0377         0.918
# 6066         0.537  0.2340  6.0    -9.706   0.0       0.0458         0.987
#
#       instrumentalness  liveness  valence    tempo  time_signature
# 5071           0.05340    0.1600    0.727  118.829             4.0
# 6069           0.09110    0.0596    0.514   75.277             4.0
# 6068           0.13800    0.0855    0.706  108.903             4.0
# 6067           0.00006    0.1130    0.242   90.215             3.0
# 6066           0.00000    0.1900    0.775  120.892             4.0

# %%
df_tracks.describe().transpose()
# Out:
#                     count           mean           std     min          25%  \
# popularity        10143.0       1.834270      5.128216     0.0       0.0000
# duration_ms       10143.0  188537.323671  97789.129824  3344.0  151399.5000
# explicit          10143.0       0.003155      0.056082     0.0       0.0000
# danceability      10143.0       0.586564      0.163355     0.0       0.4770
# energy            10143.0       0.264970      0.151218     0.0       0.1650
# key               10143.0       4.925762      3.469692     0.0       2.0000
# loudness          10143.0     -15.375837      5.401065   -60.0     -19.3475
# mode              10143.0       0.719807      0.449116     0.0       0.0000
# speechiness       10143.0       0.284304      0.365090     0.0       0.0462
# acousticness      10143.0       0.872828      0.196546     0.0       0.8395
# instrumentalness  10143.0       0.277411      0.372569     0.0       0.0000
# liveness          10143.0       0.210923      0.149883     0.0       0.1120
# valence           10143.0       0.585615      0.235069     0.0       0.4150
# tempo             10143.0     111.348108     31.079018     0.0      86.6525
# time_signature    10143.0       3.752736      0.698328     0.0       4.0000
#
#                            50%          75%          max
# popularity             0.00000       1.0000       65.000
# duration_ms       177733.00000  194873.5000  3093226.000
# explicit               0.00000       0.0000        1.000
# danceability           0.62800       0.7100        0.956
# energy                 0.24100       0.3270        1.000
# key                    5.00000       8.0000       11.000
# loudness             -14.98400     -11.4750        0.674
# mode                   1.00000       1.0000        1.000
# speechiness            0.07560       0.3530        0.969
# acousticness           0.96900       0.9920        0.996
# instrumentalness       0.00759       0.6885        0.993
# liveness               0.15800       0.2650        0.973
# valence                0.61700       0.7720        0.986
# tempo                111.15900     126.6480      221.741
# time_signature         4.00000       4.0000        5.000

# %%
most_popular=df_tracks.query('popularity>50',inplace=False).sort_values('popularity',ascending=False)
most_popular.head()
# Out:
#                           id               name  popularity  duration_ms  \
# 8095  1LGqJ3nvxpVXDWpEzq4DJD          All of Me        65.0     181440.0
# 4857  0RNxWy0PC3AyH4ThH3aGK6     Mack the Knife        55.0     201467.0
# 8096  0Otf1ZfYNIjhqFIuJk0fsy        Tea for Two        53.0     193867.0
# 8097  62Xj6x2LSWv47PtRAXrg5Z         Summertime        53.0     173493.0
# 1857  3BFRqZFLSrqtQr6cjHbAxU  Ain't Misbehavin'        51.0     237773.0
#
#       explicit              artists                  id_artists release_date  \
# 8095       0.0   ['Billie Holiday']  ['1YzCsTRb22dQkh9lghPIrp']         1933
# 4857       0.0  ['Louis Armstrong']  ['19eLuQmk9aCobbVDHc6eek']         1929
# 8096       0.0        ['Art Tatum']  ['3DtSOCXYU6o4EV0K1NgIKq']         1933
# 8097       0.0   ['Billie Holiday']  ['1YzCsTRb22dQkh9lghPIrp']         1933
# 1857       0.0      ['Fats Waller']  ['0DYWCXTkNqGFZIf67SrWEa']         1926
#
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 8095         0.504  0.0644   2.0   -14.754   0.0       0.0408         0.972
# 4857         0.673  0.3770   0.0   -14.141   1.0       0.0697         0.586
# 8096         0.358  0.4520   1.0   -13.020   1.0       0.0347         0.991
# 8097         0.628  0.2260  10.0   -14.075   0.0       0.0371         0.903
# 1857         0.515  0.2220   0.0   -16.918   0.0       0.0575         0.821
#
#       instrumentalness  liveness  valence    tempo  time_signature
# 8095          0.000004     0.174    0.403  106.994             5.0
# 4857          0.000000     0.332    0.713   88.973             4.0
# 8096          0.864000     0.140    0.525  166.973             4.0
# 8097          0.000006     0.171    0.608   99.392             4.0
# 1857          0.001930     0.190    0.350   98.358             4.0

# %%
df_tracks.set_index('release_date',inplace=True)
df_tracks.index=pd.to_datetime(df_tracks.index)
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22           6.0     126903.0       0.0              ['Uli']
# 1922-06-01           0.0      98200.0       0.0  ['Fernando Pessoa']
# 1922-03-21           0.0     181640.0       0.0  ['Ignacio Corsini']
# 1922-03-21           0.0     176907.0       0.0  ['Ignacio Corsini']
# 1922-01-01           0.0     163080.0       0.0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450  0.0   -13.338
# 1922-06-01    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630  0.0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770  1.0   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946  7.0   -27.961
# 1922-01-01    ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580  3.0   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22     1.0       0.4510         0.674            0.7440     0.151
# 1922-06-01     1.0       0.9570         0.797            0.0000     0.148
# 1922-03-21     1.0       0.0512         0.994            0.0218     0.212
# 1922-03-21     1.0       0.0504         0.995            0.9180     0.104
# 1922-01-01     0.0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature
# release_date
# 1922-02-22      0.127  104.851             3.0
# 1922-06-01      0.655  102.009             1.0
# 1922-03-21      0.457  130.418             5.0
# 1922-03-21      0.397  169.980             3.0
# 1922-01-01      0.196  103.220             4.0

# %%
df_tracks[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922-01-01 00:00:00, dtype: object

# %%
df_tracks['duration']=df_tracks['duration_ms'].apply(lambda x:round(x/1000))
df_tracks.drop('duration_ms',inplace=True,axis=1)

# %%
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22           6.0       0.0              ['Uli']
# 1922-06-01           0.0       0.0  ['Fernando Pessoa']
# 1922-03-21           0.0       0.0  ['Ignacio Corsini']
# 1922-03-21           0.0       0.0  ['Ignacio Corsini']
# 1922-01-01           0.0       0.0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450  0.0   -13.338
# 1922-06-01    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630  0.0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770  1.0   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946  7.0   -27.961
# 1922-01-01    ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580  3.0   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22     1.0       0.4510         0.674            0.7440     0.151
# 1922-06-01     1.0       0.9570         0.797            0.0000     0.148
# 1922-03-21     1.0       0.0512         0.994            0.0218     0.212
# 1922-03-21     1.0       0.0504         0.995            0.9180     0.104
# 1922-01-01     0.0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature  duration
# release_date
# 1922-02-22      0.127  104.851             3.0       127
# 1922-06-01      0.655  102.009             1.0        98
# 1922-03-21      0.457  130.418             5.0       182
# 1922-03-21      0.397  169.980             3.0       177
# 1922-01-01      0.196  103.220             4.0       163

# %%
corr_df=df_tracks.drop(['key','mode','explicit'],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=".1g",vmin=-1,vmax=1,center=0,cmap='inferno',linewidths=1,linecolor="Black")
heatmap.set_title("Correlation Heatmap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]

# %%
sample_df=df_tracks.sample(int(0.004*len(df_tracks)))

# %%
len(sample_df)
# Out:
# 40

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="loudness vs enery correlation")
# Out:
# [Text(0.5, 1.0, 'loudness vs enery correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="c").set(title="popularity vs acousticness correlation")
# Out:
# [Text(0.5, 1.0, 'popularity vs acousticness correlation')]

# %%
df_tracks['Dates']=df_tracks.index.get_level_values('release_date')
years=df_tracks.Dates.dt.year

# %%
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22           6.0       0.0              ['Uli']
# 1922-06-01           0.0       0.0  ['Fernando Pessoa']
# 1922-03-21           0.0       0.0  ['Ignacio Corsini']
# 1922-03-21           0.0       0.0  ['Ignacio Corsini']
# 1922-01-01           0.0       0.0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450  0.0   -13.338
# 1922-06-01    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630  0.0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770  1.0   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946  7.0   -27.961
# 1922-01-01    ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580  3.0   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22     1.0       0.4510         0.674            0.7440     0.151
# 1922-06-01     1.0       0.9570         0.797            0.0000     0.148
# 1922-03-21     1.0       0.0512         0.994            0.0218     0.212
# 1922-03-21     1.0       0.0504         0.995            0.9180     0.104
# 1922-01-01     0.0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature  duration      Dates
# release_date
# 1922-02-22      0.127  104.851             3.0       127 1922-02-22
# 1922-06-01      0.655  102.009             1.0        98 1922-06-01
# 1922-03-21      0.457  130.418             5.0       182 1922-03-21
# 1922-03-21      0.397  169.980             3.0       177 1922-03-21
# 1922-01-01      0.196  103.220             4.0       163 1922-01-01

# %%
sns.distplot(years,kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
